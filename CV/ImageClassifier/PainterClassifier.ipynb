# %% [markdown]
# <a href="https://colab.research.google.com/github/tohver/Portfolio/blob/master/PainterClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install voila

# %%
# !pip install fastai==2.0.13

# %%
# !voila PainterClassifier.ipynb
# Out:
# [Voila] Using /tmp to store connection files
# [Voila] Storing connection files in /tmp/voila_jmtaeelz.
# [Voila] Serving static files from /usr/local/lib/python3.6/dist-packages/voila/static.
# [Voila] Voilà is running at:
# http://localhost:8866/
# [Voila] WARNING | No web browser found: could not locate runnable browser.
# [Voila] Stopping...
# ^C

# %%
from fastai.vision.all import *
from fastai.vision.widgets import *

# %%
modelPath = Path.cwd()/"drive/My Drive/Colab Notebooks/artists/export.pkl"
model = load_learner(modelPath, cpu=True)
btnUpload = widgets.FileUpload()
out = widgets.Output()
lblPrediction = widgets.Label()

# %%
def make_prediction(x):
  lblPrediction.value = ""
  img = PILImage.create(btnUpload.data[-1])
  out.clear_output()
  with out: display(img.to_thumb(256,256))
  pred, predIdx, proba = model.predict(img)
  lblPrediction.value = f'This painting was created by {pred} with the probability of {proba[predIdx]*100:.2f}%'

# %%
btnUpload.observe(make_prediction, names=['data'])

# %%
display(VBox([widgets.Label("Upload the painting"), btnUpload, out, lblPrediction]))
